# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\maria\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in c:\users\maria\anaconda3\lib\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\maria\anaconda3\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\maria\anaconda3\lib\site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\maria\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maria\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maria\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\maria\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\maria\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\maria\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\maria\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\maria\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\maria\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. Importar librerias

# %%
import spotipy
import json
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# 2. Spotify: credenciales

# %%
CLIENT_ID = '52a14af4170949f5abd0a6fe5315c769'
CLIENT_SECRET = 'e6538dd490924858a141b61f021d5dce'

auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# 3. Spotify: token

# %%
import requests
from requests.auth import HTTPBasicAuth
client_id = CLIENT_ID
client_secret = CLIENT_SECRET
url = "https://accounts.spotify.com/api/token"
data = {
    "grant_type": "client_credentials"
}

def token_api(url): # El token cambia cada 3600 segundos (1 hora), creamos una  función para volver a obntenerlo fácilmente
    response = requests.post(url, data=data, auth=HTTPBasicAuth(client_id, client_secret))
    if response.status_code == 200:
        token = response.json()["access_token"]
        print("Token de acceso:", token)
    else:
        print("Error:", response.status_code)
        print(response.text)
token_api(url)
# Out:
# Token de acceso: BQBwwyz9hVj218pX6u9yVKSz3SwL0vW-gjUCP9Ybpujb2ZOooTF5uKYle1CsV6iGxsaZrFwIiAmiOor_O_ETlmEmzEVScV7zoevOjy8ZDGmpv6rDPYco2nABO_6Rzn9rFApCasbyh_c

# %% [markdown]
# 4. Spotify: recopilación canciones años 2019-2024 para rock, pop, reggaeton y rap

# %%
def tracks_genre (sp, genre, limit=50, total_limit=1000): # Función para obtener 1000 canciones de un género determinado 
    tracks_genre= []
    for offset in range (0, total_limit, limit): # Iteramos por las distintas páginas hasta colectar 1000 canciones
        query = f'genre:{genre} year:2019-2024'
        data = sp.search(q= query, type='track', limit=limit, offset=offset)

        for item in data['tracks']['items']: # Iteramos en la lista que nos da el API y sacamos los datos que nos interesan para añadirlos a la lista tracks_genre
            tracks_genre.append({
                    'name_track': item['name'],
                    'name_artist': item['artists'][0]['name'],
                    'genre': genre,
                    'type': item['type'],
                    'year': item['album']['release_date'][:4] })
            
    df_tracks_genre= pd.DataFrame(tracks_genre)
    df_tracks_genre.to_csv(f'{genre}_tracks.csv') # Guardamos las 1000 canciones en forma de csv

    print(df_tracks_genre.head())

    return f'{genre}_tracks.csv', df_tracks_genre

# %%
tracks_rock = tracks_genre (sp, 'rock', limit=50, total_limit= 1000)
# Out:
#                       name_track  name_artist genre   type  year
# 0  Como Si Fueras a Morir Mañana        Leiva  rock  track  2019
# 1                   La Salvación  Arde Bogotá  rock  track  2023
# 2                        El Bien  Viva Suecia  rock  track  2022
# 3                  Sin Vergüenza  Arde Bogotá  rock  track  2022
# 4                    Me Sabe Mal      MARLENA  rock  track  2023

# %%
tracks_pop = tracks_genre (sp, 'pop', limit=50, total_limit= 1000)
# Out:
#           name_track      name_artist genre   type  year
# 0  El Efecto - Remix   Rauw Alejandro   pop  track  2019
# 1               LUNA             Feid   pop  track  2023
# 2          Vagabundo  Sebastian Yatra   pop  track  2023
# 3    Algo Sencillito     Marta Santos   pop  track  2023
# 4   Die With A Smile        Lady Gaga   pop  track  2024

# %%
tracks_reggaeton = tracks_genre (sp, 'reggaeton', limit=50, total_limit= 1000)
# Out:
#                      name_track      name_artist      genre   type  year
# 0  Si Antes Te Hubiera Conocido          KAROL G  reggaeton  track  2024
# 1             El Efecto - Remix   Rauw Alejandro  reggaeton  track  2019
# 2                          LUNA             Feid  reggaeton  track  2023
# 3                     Vagabundo  Sebastian Yatra  reggaeton  track  2023
# 4          No Me Conoce - Remix           JHAYCO  reggaeton  track  2019

# %%
tracks_rap = tracks_genre (sp, 'rap', limit=50, total_limit= 1000)
# Out:
#                name_track         name_artist genre   type  year
# 0        Se Pone Las Nike                Cano   rap  track  2024
# 1                Columbia             Quevedo   rap  track  2023
# 2            VISTA AL MAR             Quevedo   rap  track  2023
# 3  Celine (with Kidd Keo)  Ghost Killer Track   rap  track  2023
# 4        PLAYA DEL INGLÉS             Quevedo   rap  track  2023

# %% [markdown]
# 5. Spotify: recopilación albums años 2019-2024 para rock, pop, reggaeton y rap

# %%
def album_genre (sp, genre, limit=50, total_limit=1000): # Función para obtener 1000 álbums de un género determinado 
    albums_genre= []
    for offset in range (0, total_limit, limit): # Iteramos por las distintas páginas hasta colectar 1000 álbums
        query = f'genre:{genre} year:2019-2024'
        data = sp.search(q= query, type='track', limit=limit, offset=offset)

        for item in data['tracks']['items']: # Iteramos en la lista que nos da el API y sacamos los datos que nos interesan para añadirlos a la lista albums_genre
            albums_genre.append({
                    'name_album': item['album']['name'],
                    'name_artist': item['artists'][0]['name'],
                    'genre': genre,
                    'type': item['album']['type'],
                    'year': item['album']['release_date'][:4] })
            
    df_albums_genre= pd.DataFrame(albums_genre) 
    df_albums_genre.to_csv(f'{genre}_albums.csv') # Guardamos las 1000 álbums en forma de csv

    print(df_albums_genre.head())

    return f'{genre}_albums.csv', df_albums_genre

# %%
albums_rock= album_genre (sp, 'rock', limit=50, total_limit=1000)
# Out:
#                     name_album  name_artist genre   type  year
# 0                      Nuclear        Leiva  rock  album  2019
# 1             COWBOYS DE LA A3  Arde Bogotá  rock  album  2023
# 2  El Amor De La Clase Que Sea  Viva Suecia  rock  album  2022
# 3                Sin Vergüenza  Arde Bogotá  rock  album  2022
# 4          1000 Primeras Veces      MARLENA  rock  album  2023

# %%
albums_pop= album_genre (sp, 'pop', limit=50, total_limit=1000)
# Out:
#           name_album      name_artist genre   type  year
# 0  El Efecto (Remix)   Rauw Alejandro   pop  album  2019
# 1     FERXXOCALIPSIS             Feid   pop  album  2023
# 2          Vagabundo  Sebastian Yatra   pop  album  2023
# 3  Poquito a Poquito     Marta Santos   pop  album  2023
# 4   Die With A Smile        Lady Gaga   pop  album  2024

# %%
albums_reggaeton= album_genre (sp, 'reggaeton', limit=50, total_limit=1000)
# Out:
#                      name_album      name_artist      genre   type  year
# 0  Si Antes Te Hubiera Conocido          KAROL G  reggaeton  album  2024
# 1             El Efecto (Remix)   Rauw Alejandro  reggaeton  album  2019
# 2                FERXXOCALIPSIS             Feid  reggaeton  album  2023
# 3                     Vagabundo  Sebastian Yatra  reggaeton  album  2023
# 4                        Famouz           JHAYCO  reggaeton  album  2019

# %%
albums_rap= album_genre (sp, 'rap', limit=50, total_limit=1000)
# Out:
#                name_album         name_artist genre   type  year
# 0                  Triana                Cano   rap  album  2024
# 1                Columbia             Quevedo   rap  album  2023
# 2      DONDE QUIERO ESTAR             Quevedo   rap  album  2023
# 3  Celine (with Kidd Keo)  Ghost Killer Track   rap  album  2023
# 4      DONDE QUIERO ESTAR             Quevedo   rap  album  2023

# %% [markdown]
# 6. Last.fm: credenciales

# %%
API_KEY = 'f0eb46d5c17e5b9b37b20631a366bb20'  
BASE_URL = 'http://ws.audioscrobbler.com/2.0/'
URL_BIOGRAFIA=f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=artist&api_key={API_KEY}&format=json"

# %% [markdown]
# 8. Last.fm: artistas

# %%
csv_files= ['rock_tracks.csv','rock_albums.csv', 'pop_tracks.csv', 'pop_albums.csv', 'reggaeton_tracks.csv', 'reggaeton_albums.csv', 'rap_tracks.csv', 'rap_albums.csv' ]

artist_track_album= []

for file_name in csv_files:
    df= pd.read_csv(file_name)
    artist = df['name_artist'].tolist()
    artist_track_album.extend(artist)

all_artist= set(artist_track_album)

all_artist # Obtenemos todos los artistas recopilados en Spotify ya que los necesitamos para el API de Last.fm
# Out:
# {'In Flames',
#  'Fall Out Boy',
#  'El Arkeologo',
#  'Ulukmanapo',
#  'Chappell Roan',
#  'SKYLERR',
#  'Gazzelle',
#  'José Pinhal',
#  'Depeche Mode',
#  'Lola Indigo',
#  'Cali Y El Dandee',
#  'Metro Boomin',
#  'Ministério Zoe',
#  'Djadja & Dinaz',
#  'Max Carra',
#  'dity inzheneriv',
#  'Parfeniuk',
#  'Adam',
#  'SZA',
#  'La Maravillosa Orquesta del Alcohol',
#  'CMAT',
#  'нексюша',
#  'Ginestà',
#  'Tego Calderón',
#  'DECO*27',
#  'Darshan Raval',
#  'BoyWithUke',
#  'en',
#  'Night Lovell',
#  'Ombladon',
#  'Y2K',
#  'Megan Thee Stallion',
#  'DJ Luian',
#  'Zucchero',
#  'Gorillaz',
#  'Bizarrap',
#  'Jin',
#  'Payal Dev',
#  'Anuel AA',
#  'Nicky Jam',
#  'Tokischa',
#  'NF',
#  'Pinhani',
#  'Imanbek',
#  'Sasso',
#  'wave to earth',
#  'Sena Şener',
#  'Tamer Ashour',
#  'JAWNY',
#  'Ele A El Dominio',
#  'Hungria',
#  'Les Cowboys Fringants',
#  'The Marías',
#  '陈村长',
#  'Molly Sandén',
#  'Marstein',
#  'Baby Keem',
#  'Anuv Jain',
#  'Rafa Pabön',
#  'Macaroni Empitsu',
#  'Riley Green',
#  'Capo Plaza',
#  'Atif Aslam',
#  'Gera MX',
#  'Johannes Oerding',
#  'Elton John',
#  'Polo G',
#  'December Avenue',
#  'Feu! Chatterton',
#  'Papa Roach',
#  'Tayc',
#  'Ramy Sabry',
#  'KEVVO',
#  'Bryan Martin',
#  'Casper Magico',
#  'Ariana Grande',
#  'Luke Bryan',
#  'PUBLIC',
#  'Jul',
#  'Diego & Victor Hugo',
#  'Bravo Metehi',
#  'Bryant Myers',
#  'L7NNON',
#  'Sohodolls',
#  'Dimitri Vegas & Like Mike',
#  'Marco Borsato',
#  'Boombox',
#  'Bring Me The Horizon',
#  'Koe Wetzel',
#  'Fabri Fibra',
#  'Juan Caoile',
#  'Bryson Tiller',
#  'The 1975',
#  'Don Pero',
#  '郑润泽',
#  'Dayme y El High',
#  'Cheema Y',
#  'Soge Culebra',
#  'Young Martino',
#  'Mesita',
#  'Rojo',
#  'The Black Skirts',
#  'Migos',
#  'Rich Amiri',
#  'Blanco',
#  'Gio Pika',
#  'DOROFEEVA',
#  'Jay Menez',
#  'Mahmoud El Leithy',
#  'Jossef',
#  'Maria Becerra',
#  'The Rolling Stones',
#  'Abdul Hannan',
#  'Manuel Turizo',
#  'Gurnazar',
#  'Moha La Squale',
#  'NAVAI',
#  'Danna',
#  'Brray',
#  "Guns N' Roses",
#  'Kore',
#  'JID',
#  'Quavo',
#  'Oques Grasses',
#  'The Offspring',
#  'Nochnye Snaipery',
#  'Маша Кондратенко',
#  'Cauty',
#  'G-Eazy',
#  'Viva Suecia',
#  'Despistaos',
#  'MHD',
#  'Bolaget',
#  'Darell',
#  'Arde Bogotá',
#  'House Of Pain',
#  'Soso Maness',
#  'Killa Fonic',
#  'RADWIMPS',
#  'La Femme',
#  'Okean Elzy',
#  'Cruz Cafuné',
#  'Vaundy',
#  'Freddie Mercury',
#  'De La Ghetto',
#  'Sara James',
#  'Geolier',
#  'JJ Lin',
#  'SHUMEI',
#  'MACAN',
#  'Nininho Vaz Maia',
#  'Conociendo Rusia',
#  'Lime Cordiale',
#  'Hitsujibungaku',
#  'Mother Mother',
#  '承桓',
#  'fromis_9',
#  'Badoxa',
#  'Josman',
#  'Cole Swindell',
#  'Lunay',
#  'Amarion',
#  "Rim'K",
#  'DJ Khaled',
#  'Kairo Keyz',
#  'Marta Santos',
#  'Rammstein',
#  'Miley Cyrus',
#  'Hamza Namira',
#  'Shoreline Mafia',
#  'Jason Aldean',
#  'Rohata Zhaba',
#  'Руслан Утюг',
#  'BOYNEXTDOOR',
#  'JANNABI',
#  'Pedro Abrunhosa',
#  'Juhn',
#  'JEREMIAS',
#  'MATRANG',
#  'Full Trunk',
#  'Три дня дождя',
#  'TWS',
#  'The Beaches',
#  'Douwe Bob',
#  'La La Love You',
#  'Tedua',
#  'Zach Top',
#  'Bresh',
#  'Kraftklub',
#  'TVORCHI',
#  'cassö',
#  'Astrid S',
#  'Nando Reis',
#  'Agrupación EUPHORIA',
#  'Brenno & Matheus',
#  'Stephen Bishop',
#  'Dani Martín',
#  'Tempo',
#  'ooes',
#  'Ramz',
#  'Baco Exu do Blues',
#  'Dolu Kadehi Ters Tut',
#  'Jasleen Royal',
#  '陳華',
#  'zhanulka',
#  'OneRepublic',
#  'Violetta Sokolova',
#  'Esteman',
#  'Prateek Kuhad',
#  'j-hope',
#  'Dylan Scott',
#  'Sam Fender',
#  'ヨルシカ',
#  'Danilo e Davi',
#  'Ruger',
#  'TOOL',
#  'Bruno Mars',
#  'Richie Campbell',
#  'Parmalee',
#  'Jerry Heil',
#  'БЕЗ ОБМЕЖЕНЬ',
#  'Galena',
#  'Almighty',
#  'Corina Smith',
#  'Jade Bolivia',
#  'Rocco Hunt',
#  'Ella Mai',
#  'Mirella',
#  'Timal',
#  'Sheena Ringo',
#  'Amenazzy',
#  'YOASOBI',
#  'DEKKO',
#  'Bakr',
#  'Maki',
#  'Little River Band',
#  'Cigarettes After Sex',
#  'Piti Fernández',
#  'Mustard',
#  'Patsyki Z Franeka',
#  'Lidia',
#  'Domingues',
#  'Dua Lipa',
#  '小阿七',
#  'Pietro Basile',
#  'Karmen',
#  'Goldband',
#  'MONATIK',
#  'Cardi B',
#  'Faheem Abdullah',
#  'Hey',
#  'Duke Dumont',
#  'Yandel',
#  'Sanctus Real',
#  'ELYELLA',
#  'Stupeflip',
#  'Konstantin',
#  'beabadoobee',
#  'Rawayana',
#  'Massar Egbari',
#  'Tam Sir',
#  'Kali Uchis',
#  'Trippie Redd',
#  'ROSALÍA',
#  'Artem Pivovarov',
#  'Nerd Connection',
#  'The Afters',
#  'Sebastian Yatra',
#  'Nuno Ribeiro',
#  'Xavier Wulf',
#  'Gloria Groove',
#  'Sylwia Grzeszczak',
#  'A$AP Rocky',
#  'Тінь Сонця',
#  'Muslim - مُسلِم',
#  'Damso',
#  'Alejo',
#  'smokedope2016',
#  'Tyler, The Creator',
#  'Salastkbron',
#  'Nothing But Thieves',
#  'VovaZiLvova',
#  'Landy',
#  'Tokyo Incidents',
#  'Emmanuel Horvilleur',
#  'Sam Hunt',
#  'Urszula',
#  'Tate McRae',
#  'Özdemir Erdoğan',
#  'The Black Keys',
#  'Lazza',
#  'Pusho',
#  'Sfera Ebbasta',
#  'Lil Tjay',
#  'Yitai Wang',
#  'Snow Strippers',
#  'Shakira',
#  'Fito y Fitipaldis',
#  'Zerb',
#  'Jean-Louis Aubert',
#  'SDM',
#  'Trevor Daniel',
#  'Lalo Ebratt',
#  'Da-iCE',
#  'BIN',
#  'ANNA',
#  'gins&melodies',
#  'Perdenin Ardındakiler',
#  'Senidah',
#  'mgk',
#  'Powfu',
#  'Destroy Lonely',
#  'Javiielo',
#  'Mike Bahía',
#  'Sasha Chemerov',
#  'Aarne',
#  'SIMONA',
#  'Silvestre y La Naranja',
#  'Lary Over',
#  'Slipknot',
#  'Tino Martin',
#  'Poshlaya Molly',
#  'Reik',
#  'ALLMO$T',
#  'Israel & Rodolffo',
#  'Beendo Z',
#  'Bee Gees',
#  'Imagine Dragons',
#  'Kaan Boşnak',
#  'Ozbi',
#  'Charlotte Cardin',
#  'Gunna',
#  'AKRIILA',
#  'Alex Rose',
#  'Soprano',
#  'Тоня Матвієнко',
#  'Yasin',
#  'Montez',
#  'Troy Kingi',
#  'МОТ',
#  'JACKBOYS',
#  'XXXTENTACION',
#  'MiyaGi',
#  'Moji x Sboy',
#  'Thalles Roberto',
#  'Clairo',
#  'Stick Figure',
#  'Aydilge',
#  'Дeva',
#  'David Guetta',
#  'Twin Tribes',
#  'MARLENA',
#  'Khrystyna Soloviy',
#  'Oney1',
#  'Lil Peep',
#  'Вектор А',
#  'Sachet Tandon',
#  'Chris Tomlin',
#  'Young Jonn',
#  'quannnic',
#  'Pinto Picasso',
#  'Riton',
#  'BLUE ENCOUNT',
#  '100 gecs',
#  'CHEEV',
#  'Ramy Gamal',
#  'Miranda!',
#  'AUR',
#  'La T y La M',
#  'Yera',
#  'Young Thug',
#  'Luchè',
#  'BIGBANG',
#  'Subcarpaţi',
#  'Soolking',
#  'Nio Garcia',
#  'RONDÉ',
#  'Duran Duran',
#  'Turf',
#  'Serko',
#  '蒋小呢',
#  'Lyapis Trubetskoy',
#  'Lil Baby',
#  'Mavi Gri',
#  'Myles Smith',
#  'Ganso',
#  'Taylor Swift',
#  'Dadju',
#  'Dessita',
#  'Jay Wheeler',
#  'La Santa Grifa',
#  'Alex Zurdo',
#  'Lamatrix',
#  'Siddhartha',
#  'MY FIRST STORY',
#  'Epolets',
#  'Alfa',
#  'Vegedream',
#  'Dalex',
#  'd4vd',
#  '高爾宣 OSN',
#  'Vanesa Martín',
#  'Charli xcx',
#  'Labrinth',
#  'Dermot Kennedy',
#  'Leebrian',
#  'Arctic Monkeys',
#  'Bekar',
#  'Glass Animals',
#  'Haquil',
#  'Yebba',
#  'MODELKI',
#  'back number',
#  'Luidji',
#  'Balthazar',
#  'Kenshi Yonezu',
#  'Yung Gravy',
#  'Cazzu',
#  'Megan Moroney',
#  'UZI',
#  'Agust D',
#  'Shinova',
#  'Yeat',
#  'Linh',
#  'DJ Scheme',
#  'Bigflo & Oli',
#  'Tember Blanche',
#  'Ryan Castro',
#  'Tyga',
#  'Stray Kids',
#  'Brunori Sas',
#  'Babasonicos',
#  'Mitraz',
#  'DaniLeigh',
#  'Old Mervs',
#  'Linkin Park',
#  'Animal Jazz',
#  'Zkr',
#  'Shaka Ponk',
#  'Hotel Ugly',
#  'Tamer Hosny',
#  'PNL',
#  'Señor Loop',
#  'Marracash',
#  'Izïa',
#  'Fara Zahar',
#  'Emir Can İğrek',
#  'Cults',
#  'Werenoi',
#  'Ryokuoushoku Shakai',
#  'SFDK',
#  'Leningrad',
#  'КОСМОНАВТОВ НЕТ',
#  'Ovy On The Drums',
#  'Hoshi',
#  'Valentino GRM',
#  '$uicideboy$',
#  'Seyi Vibez',
#  'Miss Montreal',
#  'Nina Chuba',
#  'Dopebwoy',
#  'Reol',
#  'Monaky',
#  'Puya',
#  'Vacra',
#  'Houari',
#  'Foster The People',
#  'Justin Bieber',
#  'Madrigal',
#  'Asake',
#  'Cochise',
#  'Alonzo',
#  'Dominic Fike',
#  'Guitarricadelafuente',
#  'Sonny Fodera',
#  'La Joaqui',
#  'Empire Of The Sun',
#  'Ofenbach',
#  'Arcángel',
#  'Matheus & Kauan',
#  'Miky Woodz',
#  'Los Enanitos Verdes',
#  'Alex Warren',
#  'Indochine',
#  'Daddy Yankee',
#  'Catfish and the Bottlemen',
#  'Therapie TAXI',
#  'алёна швец.',
#  'Omy de Oro',
#  'Calema',
#  'Pinguini Tattici Nucleari',
#  'Shablo',
#  'Queen',
#  'Niro',
#  'Robin Schulz',
#  'The Mary Wallopers',
#  'BUMP OF CHICKEN',
#  'El Blachy',
#  'yeule',
#  'Myke Towers',
#  'Marshmello',
#  'Yung Bleu',
#  'Tiakola',
#  'kizaru',
#  'Davido',
#  'step.jad',
#  'Racoon',
#  'Chencho Corleone',
#  'Aditya Rikhari',
#  'Jelly Roll',
#  'BABYMETAL',
#  'El Barrio',
#  'Svyatoslav Vakarchuk',
#  'OKS',
#  'Hombres G',
#  'Bailey Zimmerman',
#  'IVE',
#  'Kehlani',
#  'Tan Bionica',
#  'JONY',
#  'Semicenk',
#  'Big Thief',
#  'Evdeki Saat',
#  'Las Pastillas del Abuelo',
#  'A Boogie Wit da Hoodie',
#  'Nahir',
#  'Yng Lvcas',
#  'King',
#  'Lee Brice',
#  'Lewis Capaldi',
#  'ששון איפרם שאולוב',
#  'That Mexican OT',
#  'DaBaby',
#  'Dayglow',
#  'Billie Eilish',
#  'Sabrina Carpenter',
#  '$NOT',
#  'Future',
#  'Dhanda Nyoliwala',
#  'Freddie Dredd',
#  'Sean Paul',
#  'Leiva',
#  'Krisko',
#  'Дайте танк (!)',
#  'Mikel Izal',
#  'ilyTOMMY',
#  'Мёртвые Дельфины',
#  '5 Seconds of Summer',
#  'LOUTA',
#  'The Raconteurs',
#  'Alena Omargalieva',
#  'Karan Aujla',
#  'NATHY PELUSO',
#  'Arizona Zervas',
#  'Lost Frequencies',
#  'James Arthur',
#  'The Unsleeping',
#  'Twenty One Pilots',
#  'Zhadan i Sobaky',
#  'El Kuelgue',
#  'Silica Gel',
#  'MamaRika',
#  'Juice WRLD',
#  'Dreamville',
#  'Kodak Black',
#  'Harry Styles',
#  'Ninho',
#  'BONES',
#  'Yuuri',
#  'Smash Into Pieces',
#  'Екатерина Яшникова',
#  'KnyaZz',
#  'DA Uzi',
#  'B.U.G. Mafia',
#  'Luis Vega',
#  'Matuê',
#  'Fiolet',
#  'Maanu',
#  'Blessd',
#  '24kGoldn',
#  '1nonly',
#  'Procol Harum',
#  'Thomas Rhett',
#  'FACE',
#  'Cano',
#  'Bad Gyal',
#  'Slayter',
#  'El Zar',
#  'Мэйби Бэйби',
#  'Maha Ftouni',
#  'bbno$',
#  'DEAD BLONDE',
#  'Green Day',
#  'SPYAIR',
#  'Treaty Oak Revival',
#  'Troye Sivan',
#  'Boza',
#  'King Von',
#  'Alcolirykoz',
#  'Maretu',
#  'Clams Casino',
#  'Flow G',
#  'Anastasia',
#  'Emanero',
#  'Spacey Jane',
#  'Henry Moodie',
#  'Alex Velea',
#  'Playboi Carti',
#  'Dorian',
#  'Japanese Breakfast',
#  'Eve',
#  'ANNA ASTI',
#  'лампабикт',
#  'Gambi',
#  'Eddy de Pretto',
#  'A$AP Ferg',
#  'Camilo',
#  'Pinky SD',
#  'анастимоза',
#  'Takida',
#  'Jay Smith',
#  'SKAZZ',
#  'Bagossy Brothers Company',
#  'Dean Lewis',
#  'Ceky Viciny',
#  'Maná',
#  'PENOMECO',
#  'Melendi',
#  'Bayaan',
#  'YAKTAK',
#  'Miguel Campello',
#  'UNISON SQUARE GARDEN',
#  'El Alfa',
#  'AYLIVA',
#  'Tiësto',
#  'Paris Paloma',
#  'Maluma',
#  'WOODZ',
#  'Pignoise',
#  'Yüzyüzeyken Konuşuruz',
#  'Florida Georgia Line',
#  'Kchiporros',
#  'Justin Quiles',
#  'Veintiuno',
#  'Mark Ambor',
#  'Jimin',
#  'Delaossa',
#  'Tucker Wetmore',
#  'Danny Vera',
#  'Kenya Grace',
#  'SunKissed Lola',
#  'Videoclub',
#  'DJ Damyan',
#  'ANAVITÓRIA',
#  'Djordan',
#  'Hov1',
#  'Noriel',
#  'LAGOS',
#  'Victor Leksell',
#  'Jan Smit',
#  'Franglish',
#  'Manuel Carrasco',
#  'L2B',
#  'Montell Fish',
#  'Moneybagg Yo',
#  'twocolors',
#  'Mambo Kingz',
#  'NAFTA',
#  'LIBERATO',
#  'Kaza',
#  'Falling In Reverse',
#  'Odyn v Kanoe',
#  'Don Patricio',
#  'The Neighbourhood',
#  'Dhruv',
#  'Brytiago',
#  'Rvssian',
#  'Lizzy McAlpine',
#  'Hoobastank',
#  'Peter Fox',
#  'Canozan',
#  'АСАФАТОV',
#  'Nerry Money',
#  'Voz Veis',
#  'Roddy Ricch',
#  '卢卢快闭嘴',
#  'Olivia Rodrigo',
#  'Coez',
#  'WANIMA',
#  'Rauw Alejandro',
#  'Lil Durk',
#  'Dani Fernández',
#  'IRAIDA',
#  'The Hatters',
#  'KAROL G',
#  'Miro',
#  'Mau y Ricky',
#  'Swedish House Mafia',
#  'Lilly Wood and The Prick',
#  'Conan Gray',
#  'Nicole Cherry',
#  'Akhil',
#  'Zola',
#  'Дора',
#  'Созвездие Отрезок',
#  'Paula Mattheus',
#  'Jon Pardi',
#  'Cem Adrian',
#  'VUNK',
#  'Victony',
#  'Phil Wickham',
#  'Gigi Perez',
#  'Parmish Verma',
#  'NATTI NATASHA',
#  'Robi Guid',
#  'Kygo',
#  'Felipe e Rodrigo',
#  'Matias Damásio',
#  'Phil Collins',
#  'Novelbright',
#  'Lana Del Rey',
#  'elijah woods',
#  'YNW Melly',
#  'Wiz Khalifa',
#  'Monetochka',
#  'Menor Menor',
#  'indigo la End',
#  'Lil Tracy',
#  'SE SO NEON',
#  'Wiktor Dyduła',
#  'Hamza',
#  'Altamira',
#  'Ñejo',
#  'DYSTINCT',
#  'Kofs',
#  'Tyler Braden',
#  'Don Omar',
#  'Danny Ocean',
#  'YUNGBLUD',
#  'Marko Perković Thompson',
#  'Metallica',
#  'Схожа',
#  'Doja Cat',
#  'Rose Villain',
#  'Lauana Prado',
#  'Camila Cabello',
#  'Internet Money',
#  'Dagny',
#  'GIMS',
#  'Joey Montana',
#  'Travis Scott',
#  'Pop Smoke',
#  'Russ',
#  'Young Stoner Life',
#  'marc indigo',
#  'Kaśka Sochacka',
#  'DJ Tao',
#  'Cruzando El Charco',
#  'Maikel Delacalle',
#  'Sting',
#  'кис-кис',
#  'ODUMODUBLVCK',
#  'G Herbo',
#  'Mila Robert',
#  'Jack Black',
#  'Kaique e Felipe',
#  'Lola Young',
#  'Maiara & Maraisa',
#  'Tame Impala',
#  'Kari Jobe',
#  'Flo Milli',
#  'Caramelos De Cianuro',
#  'KOLA',
#  'Shiva',
#  'Lil Tecca',
#  'Hugo & Guilherme',
#  'Vivienne Mort',
#  'TRASH',
#  'Alex Gargolas',
#  'Franco "El Gorilla"',
#  'SEREBRO',
#  'James Hype',
#  'alyona alyona',
#  'Afrodisiaco',
#  'Walls',
#  'Benny Jamz',
#  'J Balvin',
#  'Skylar Grey',
#  'Kendrick Lamar',
#  'Adrianne Lenker',
#  'Vance Joy',
#  'Offset',
#  'DZIDZIO',
#  '1da Banton',
#  'Tems',
#  'Ghost',
#  'SAINt JHN',
#  'zzoilo',
#  'El Plan De La Mariposa',
#  'rares',
#  'AP Dhillon',
#  'Don Miguelo',
#  'Jack Harlow',
#  'Malandro',
#  'Natos y Waor',
#  'Darkoo',
#  'LBI利比',
#  'for KING & COUNTRY',
#  'Walker Hayes',
#  'Tobias Rahim',
#  'NILETTO',
#  'Achille Lauro',
#  'Kaifi Khalil',
#  'Tsvetelina Yaneva',
#  'Super Yei',
#  'ZOO',
#  'Aimer',
#  'Serú Girán',
#  'shirebound',
#  'Naza',
#  'Ahmed Saad',
#  'The Kolors',
#  'NLE Choppa',
#  'Akhil Sachdeva',
#  'Brent Cobb',
#  'Kanye West',
#  'ILLIT',
#  'Rod Wave',
#  'Don Toliver',
#  'Deejay Telio',
#  "Hernan y La Champion's Liga",
#  'DJ Babs',
#  'Wilmer Roberts',
#  'Diljit Dosanjh',
#  'Whiskey Myers',
#  'Tom Petty',
#  'Cup of Joe',
#  'OBOY',
#  'İkiye On Kala',
#  'Kozak System',
#  'Pixies',
#  'Jon Z',
#  'sanah',
#  'Lil Yachty',
#  'JHAYCO',
#  'Скрябін',
#  'D.O.D',
#  'Wisin & Yandel',
#  'Summer Walker',
#  'PARTYNEXTDOOR',
#  'FloyyMenor',
#  'Zaho de Sagazan',
#  'MC Xenon',
#  'Olly',
#  'Tory Lanez',
#  'The La Planta',
#  'Joey Valence & Brae',
#  'Black Jonas Point',
#  'Son Mieux',
#  'SPITZ',
#  'Ziferblat',
#  'NAZVA',
#  'Koba LaD',
#  'Mert Demir',
#  'Eminem',
#  'Nicky Youre',
#  'Don Henley',
#  'SKAI',
#  'The Lumineers',
#  'Jung Kook',
#  'BNXN',
#  'Antytila',
#  'Miranda',
#  'Karna.val',
#  'Blanco Brown',
#  'HammAli & Navai',
#  'The Minds Of 99',
#  "Jok'air",
#  'Jesús Adrián Romero',
#  'André Hazes Jr.',
#  'Fatma Turgut',
#  'SYML',
#  'Natiruts',
#  'Capper',
#  'Pashanim',
#  'Kip Moore',
#  'Los Fabulosos Cadillacs',
#  'Wellboy',
#  'Leto',
#  'sakanaction',
#  'Gerry Cinnamon',
#  'N.Flying',
#  'BINI',
#  'KALEO',
#  'Masoom Sharma',
#  'Milly',
#  'Royel Otis',
#  'Chico',
#  'The Urs',
#  'Vũ.',
#  'Benson Boone',
#  'Шугар',
#  'Suki Waterhouse',
#  'IV Of Spades',
#  'Tainy',
#  'Cabron',
#  'Pipe Bueno',
#  'Ren Ran',
#  'Madison Beer',
#  'CHiCO with HoneyWorks',
#  'Bárbara Bandeira',
#  'Chris Brown',
#  'Disiz',
#  'LiSA',
#  'Chris Jedi',
#  'RAYE',
#  'Oana Radu',
#  'Piso 21',
#  'The Hardkiss',
#  'Luis Fonsi',
#  'Arcane',
#  'The Doors',
#  'David Bisbal',
#  'Black Eyed Peas',
#  'AMI',
#  'Marvel Boy',
#  'Generación 12',
#  'Juli',
#  'Adamlar',
#  'Медовий Полин',
#  'Green Montana',
#  'Kaaris',
#  '[Alexandros]',
#  'Chimbala',
#  'OFFICIAL HIGE DANDISM',
#  'Fernandinho',
#  'Ke Personajes',
#  'Jazzy',
#  'La Pantera',
#  'Måneskin',
#  'Sufle',
#  'BARBEL',
#  'Japiaguar',
#  'Capitão Fausto',
#  'Duman',
#  'Sleepy Hallow',
#  'Pornofilmy',
#  'PLK',
#  'Alex Sensation',
#  'SCH',
#  'Brent Faiyaz',
#  'NewJeans',
#  'Gazo',
#  'Naps',
#  'Indio Solari',
#  'Richy Mitch & The Coal Miners',
#  'Nate Smith',
#  "Heuss L'enfoiré",
#  'Gambino',
#  'Noah Kahan',
#  'DI-RECT',
#  'Nívea Soares',
#  'Сны Саламандры',
#  'Goth Babe',
#  'Kaspiyskiy Gruz',
#  'Jarabe De Palo',
#  'Adele',
#  'Ed Sheeran',
#  'Hard GZ',
#  'KXLLSWXTCH',
#  'Greeicy',
#  'Chystemc',
#  'The Beatles',
#  'Domiy',
#  'Favé',
#  'Dímelo Flow',
#  'Ufuk Beydemir',
#  'MIRA',
#  'Lil God Dan',
#  'Santiano',
#  'Tedi Aleksandrova',
#  'Andy Grammer',
#  'Coldplay',
#  'Marc Seguí',
#  'QUEEN BEE',
#  'SUDA MASAKI',
#  'PinkPantheress',
#  'Nekfeu',
#  'Ghost Killer Track',
#  'Lil Uzi Vert',
#  'DTF',
#  'LE SSERAFIM',
#  'Sidhu Moose Wala',
#  'Letters to Lions',
#  'Maes',
#  'RM',
#  'Skindred',
#  'NAPA',
#  'Rob Deniel',
#  'Volbeat',
#  ...}

# %% [markdown]
# 7. Last.fm: obtener biografía, listeners y playcounts de los artistas encontrados en Spotify

# %%
import re # Usamos Regex para limpiar los datos

# %%
artist_info=[] # Lista para guardar la información de los artistas

for artist in all_artist:
    URL_BIO=f"http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={artist}&api_key={API_KEY}&format=json" # Entramos al API cambiando el nombre del artista en la URL
    params_info = {
        'method': 'artist.getinfo',
        'artist': artist,
        'api_key': API_KEY,
        'format': 'json'
        }
    response_info = requests.get(URL_BIO, params=params_info)
    data_info = response_info.json()
    
    if 'artist' in data_info:

        bio_summary = data_info['artist'].get('bio', {}).get('summary', '')

        bio_text = re.sub(r'<[^>]+>', '', bio_summary).strip()  # Con Regex eliminar todas las etiquetas HTML

        if bio_text == 'Read more on Last.fm': # Si el texto limpio solo tiene esa info, establecer como 'None'
            bio_summary = 'None'
        else:
            bio_summary = bio_text

        artist_data = {
            'Artist': artist,
            'Biography': bio_summary,
            'Listeners': data_info['artist'].get('stats', {}).get('listeners', "Sin datos"),
            'Playcount': data_info['artist'].get('stats', {}).get('playcount', "Sin datos")
            }
    
    else: # Si el artista no aparece en el API nos informa de esta forma
        artist_data = {
            'Artist': artist,
            'Biography': None,
            'Listeners': None,
            'Playcount': None
            }
    
    artist_info.append(artist_data)

df_artist_info= pd.DataFrame(artist_info) 

df_artist_info.to_csv('artist_info.csv') # Guardamos la información del artista en csv

df_artist_info.head()
# Out:
#           Artist                                          Biography Listeners  \
# 0      In Flames  In Flames is a Swedish heavy metal band, forme...   1460737
# 1   Fall Out Boy  Fall Out Boy are a pop punk band formed in 200...   4364642
# 2   El Arkeologo  Juan Carlos Fonnegra Toro, más conocido como G...      8973
# 3     Ulukmanapo                                               None     14869
# 4  Chappell Roan  Kayleigh Rose Amstutz (born February 19, 1998)...   1966735
#
#    Playcount
# 0  169668021
# 1  314020511
# 2     110581
# 3     194768
# 4  222787118

# %%
similar_artist=[] # Lista para guardar los artistas similares

for artist in all_artist:
    URL_SIMILAR = f"http://ws.audioscrobbler.com/2.0/?method=artist.getsimilar&artist={artist}&api_key={API_KEY}&format=json" # Entramos al API cambiando el nombre del artista en la URL    params_info = {
    params_info = {
        'method': 'artist.getsimilar',
        'artist': artist,
        'api_key': API_KEY,
        'format': 'json'
    }
    response_info = requests.get(URL_SIMILAR, params=params_info)
    data_info = response_info.json()

    similar = data_info.get('similarartists', {}).get('artist', [])
    
    name_similar = [similar_artist['name'] for similar_artist in similar] # Creamos una lista con los nombres de varios artistas similares
    
    if similar:
        name_similar = [similar_artist['name'] for similar_artist in similar]

        artist_data = {
            'Artist': artist,
            'Similar':  ", ".join(name_similar)
        }
    else: # Si el artista no tiene esta info en la API aparece de esta forma
        artist_data = {
            'Artist': artist,
            'Similar': None
        }
    
    similar_artist.append(artist_data)

df_similar_artist= pd.DataFrame(similar_artist) 

df_similar_artist.to_csv('similar_artist.csv') # Guardamos la información del artista en csv

df_similar_artist.head()
# Out:
#           Artist                                            Similar
# 0      In Flames  Soilwork, Dark Tranquillity, The Halo Effect, ...
# 1   Fall Out Boy  Patrick Stump, Cobra Starship, Panic! at the D...
# 2   El Arkeologo  Luis7Lunes, No Rules Clan, Mañas Ru-Fino, Ceja...
# 3     Ulukmanapo  Jamik, Кисло-Сладкий & Bonah, Truwer, Вектор А...
# 4  Chappell Roan  Sabrina Carpenter, Olivia Rodrigo, Conan Gray,...

# %%
top_tracks = []  # Lista para guardar la información de las canciones top

for artist in all_artist:
    URL_TOP_TRACKS = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artist}&api_key={API_KEY}&format=json"
    
    response_info = requests.get(URL_TOP_TRACKS)
    data_info = response_info.json()

    if "toptracks" in data_info and "track" in data_info["toptracks"]:
        for track in data_info["toptracks"]["track"]:
            artist_data = {
                'Artist': artist,
                'Track': track.get('name', None),
                'Listeners': track.get('listeners', None),
                'Playcount': track.get('playcount', None)
            }
            top_tracks.append(artist_data)
    else: # Si no hay info del artista, añadimos una entrada con valores None
        artist_data = {
            'Artist': artist,
            'Track': None,
            'Listeners': None,
            'Playcount': None
        }
        top_tracks.append(artist_data)
                                       
df_top_tracks = pd.DataFrame(top_tracks)
df_top_tracks.to_csv('top_tracks.csv')  # Guardamos en csv

df_top_tracks.head()
# Out:
#       Artist              Track Listeners Playcount
# 0  In Flames  Only for the Weak    390607   4383432
# 1  In Flames     Take This Life    377884   3887480
# 2  In Flames       Come Clarity    344502   3890343
# 3  In Flames    Cloud Connected    331549   3461801
# 4  In Flames    The Quiet Place    273713   3025482

# %% [markdown]
# 8. Pasar base de datos a MySQL

# %%
pip install sqlalchemy mysql-connector-python
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\maria\anaconda3\lib\site-packages (2.0.34)
# Requirement already satisfied: mysql-connector-python in c:\users\maria\anaconda3\lib\site-packages (9.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\maria\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\maria\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+mysqlconnector://root:AlumnaAdalab@127.0.0.1/bd_musicstream')

def insert_df_mysql(df, table_name, engine, if_exists='append'): # Creamos una función para pasar todos los DF creados a MySQL
    df.to_sql(name=table_name, con=engine, if_exists=if_exists, index=False)
    print(f"Datos insertados correctamente en la tabla '{table_name}'.")

# %%
df_tracks_rock= pd.read_csv('rock_tracks.csv')
insert_df_mysql(df_tracks_rock, 'rock_tracks', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'rock_tracks'.

# %%
df_tracks_pop= pd.read_csv('pop_tracks.csv')
insert_df_mysql(df_tracks_pop, 'pop_tracks', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'pop_tracks'.

# %%
df_tracks_reggaeton= pd.read_csv('reggaeton_tracks.csv')
insert_df_mysql(df_tracks_reggaeton, 'reggaeton_tracks', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'reggaeton_tracks'.

# %%
df_tracks_rap= pd.read_csv('rap_tracks.csv')
insert_df_mysql(df_tracks_rap, 'rap_tracks', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'rap_tracks'.

# %%
df_albums_rock= pd.read_csv('rock_albums.csv')
insert_df_mysql(df_albums_rock, 'rock_albums', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'rock_albums'.

# %%
df_albums_pop= pd.read_csv('pop_albums.csv')
insert_df_mysql(df_albums_pop, 'pop_albums', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'pop_albums'.

# %%
df_albums_reggaeton= pd.read_csv('reggaeton_albums.csv')
insert_df_mysql(df_albums_reggaeton, 'reggaeton_albums', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'reggaeton_albums'.

# %%
df_albums_rap= pd.read_csv('rap_albums.csv')
insert_df_mysql(df_albums_rap, 'rap_albums', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'rap_albums'.

# %%
insert_df_mysql(df_similar_artist, 'similar_artist', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'similar_artist'.

# %%
insert_df_mysql(df_artist_info, 'artist_info', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'artist_info'.

# %%
insert_df_mysql(df_top_tracks, 'top_tracks', engine, if_exists='append')
# Out:
# Datos insertados correctamente en la tabla 'top_tracks'.
